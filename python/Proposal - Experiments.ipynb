# %%
from ratatoskr import core, common, ndga, charts
from bokeh.plotting import output_notebook
output_notebook()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4b2e570fbeac> in <module>()
# ----> 1 from ratatoskr import core, common, ndga, charts
#       2 from bokeh.plotting import output_notebook
#       3 output_notebook()
#
# ImportError: /home/felix/anaconda3/envs/ratatoskr/lib/python3.6/site-packages/ratatoskr/core.so: undefined symbol: _ZN4core7Session5buildER7BuilderR19EvolutionaryNetworkR16BreedingOperator

# %%
problem = common.Problem(ndga.EvaluationFunctions.evalOneMax(), 50, 20)
session = ndga.Session(problem)

conf = session.configuration
conf.system.complete = True
conf.system.epochs = 10
conf.system.episodes = 1000
conf.system.generations = 50

conf.initializer.threads = 3
conf.evaluator.threads = 3
conf.breeder.threads = 3

system = session.build()
system.run()

stat1 = s1.statistics
charts.rfc(stat1)

# %% [markdown]
# # Experiment 1: Ideal One Max

# %%
problem = common.Problem(ndga.EvaluationFunctions.evalOneMax(), 50, 10)
with ndga.Session(problem) as session:
    session.configuration.system.complete = True
    session.configuration.system.epochs = 10
    session.configuration.system.episodes = 1000
    session.configuration.system.generations = 50
    session.configuration.initializer.threads = 3
    session.configuration.evaluator.threads = 3
    session.configuration.breeder.threads = 3
    system = session.build()
    system.run()

# %%
s1 = system
stat1 = s1.statistics
charts.rfc(stat1)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="229a2b52-2301-481e-b167-ff46f658b76e"></div>
# </div>

# %% [markdown]
# # Experiment 2: Narrowed One Max

# %%
problem = common.Problem(ndga.EvaluationFunctions.evalNarrowedOneMax(), 50, 10)
session = ndga.Session(problem)
session.configuration.system.complete = True
session.configuration.system.epochs = 10
session.configuration.system.episodes = 1000
session.configuration.system.generations = 50
session.configuration.initializer.threads = 3
session.configuration.evaluator.threads = 3
session.configuration.breeder.threads = 3
system = session.build()
system.run()

# %%
s2 = system
stat2 = s2.statistics
charts.rfc(stat2)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="43b8410b-1f96-4feb-8f0b-1d639a0c92ec"></div>
# </div>

# %% [markdown]
# # Experiment 3: Deceptive One Max

# %%
problem = common.Problem(ndga.EvaluationFunctions.evalDeceptiveOneMax(), 50, 10)
session = ndga.Session(problem)
session.configuration.system.complete = True
session.configuration.system.epochs = 10
session.configuration.system.episodes = 1000
session.configuration.system.generations = 50
session.configuration.initializer.threads = 3
session.configuration.evaluator.threads = 3
session.configuration.breeder.threads = 3
system = session.build()
system.run()

# %%
s3 = system
stat3 = s3.statistics
charts.rfc(stat3)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7596f8ca-9a3d-4a3b-a5f1-5dc0668e79e5"></div>
# </div>
